# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 

import warnings
warnings.filterwarnings("ignore")
import os
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# # Charlotte

# %%
irradiance_data = pd.read_csv('Charlotte/653351892e546d5d55892a5e2a054320/Modified_1045140_35.21_-80.86_2006.csv')
irradiance_data['LocalTime'] = pd.to_datetime(irradiance_data[['Year', 'Month', 'Day', 'Hour', 'Minute']])
irradiance_data["TIME"] = pd.to_datetime(irradiance_data["LocalTime"]).dt.time
irradiance_data["DATE"] = pd.to_datetime(irradiance_data["LocalTime"]).dt.date
irradiance_data = irradiance_data[irradiance_data['Minute'] == 0]
irradiance_data.describe().style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_0dc2b_row0_col0, #T_0dc2b_row0_col1, #T_0dc2b_row0_col2, #T_0dc2b_row0_col3, #T_0dc2b_row0_col4, #T_0dc2b_row0_col5, #T_0dc2b_row0_col6, #T_0dc2b_row0_col7, #T_0dc2b_row0_col8, #T_0dc2b_row0_col9, #T_0dc2b_row0_col10, #T_0dc2b_row0_col11, #T_0dc2b_row0_col12, #T_0dc2b_row0_col13, #T_0dc2b_row0_col14, #T_0dc2b_row0_col15, #T_0dc2b_row0_col16, #T_0dc2b_row0_col17, #T_0dc2b_row0_col18, #T_0dc2b_row0_col19, #T_0dc2b_row0_col20, #T_0dc2b_row0_col21, #T_0dc2b_row0_col22, #T_0dc2b_row0_col23 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_0dc2b_row1_col0, #T_0dc2b_row3_col0, #T_0dc2b_row4_col0, #T_0dc2b_row5_col0, #T_0dc2b_row6_col0, #T_0dc2b_row7_col0 {
#   background-color: #3ac5ff;
#   color: #000000;
# }
# #T_0dc2b_row1_col1, #T_0dc2b_row1_col2, #T_0dc2b_row1_col3, #T_0dc2b_row1_col4, #T_0dc2b_row1_col7, #T_0dc2b_row1_col8, #T_0dc2b_row1_col9, #T_0dc2b_row1_col11, #T_0dc2b_row1_col18, #T_0dc2b_row1_col19, #T_0dc2b_row1_col21, #T_0dc2b_row1_col22, #T_0dc2b_row1_col23, #T_0dc2b_row2_col0, #T_0dc2b_row2_col1, #T_0dc2b_row2_col2, #T_0dc2b_row2_col3, #T_0dc2b_row2_col4, #T_0dc2b_row2_col7, #T_0dc2b_row2_col8, #T_0dc2b_row2_col9, #T_0dc2b_row2_col10, #T_0dc2b_row2_col11, #T_0dc2b_row2_col12, #T_0dc2b_row2_col17, #T_0dc2b_row2_col18, #T_0dc2b_row2_col19, #T_0dc2b_row2_col21, #T_0dc2b_row2_col22, #T_0dc2b_row2_col23, #T_0dc2b_row3_col1, #T_0dc2b_row3_col2, #T_0dc2b_row3_col3, #T_0dc2b_row3_col4, #T_0dc2b_row3_col5, #T_0dc2b_row3_col6, #T_0dc2b_row3_col7, #T_0dc2b_row3_col8, #T_0dc2b_row3_col9, #T_0dc2b_row3_col10, #T_0dc2b_row3_col11, #T_0dc2b_row3_col13, #T_0dc2b_row3_col14, #T_0dc2b_row3_col15, #T_0dc2b_row3_col16, #T_0dc2b_row3_col17, #T_0dc2b_row3_col18, #T_0dc2b_row3_col19, #T_0dc2b_row3_col20, #T_0dc2b_row3_col21, #T_0dc2b_row3_col22, #T_0dc2b_row3_col23, #T_0dc2b_row4_col1, #T_0dc2b_row4_col2, #T_0dc2b_row4_col3, #T_0dc2b_row4_col4, #T_0dc2b_row4_col5, #T_0dc2b_row4_col6, #T_0dc2b_row4_col7, #T_0dc2b_row4_col8, #T_0dc2b_row4_col9, #T_0dc2b_row4_col11, #T_0dc2b_row4_col13, #T_0dc2b_row4_col14, #T_0dc2b_row4_col15, #T_0dc2b_row4_col16, #T_0dc2b_row4_col18, #T_0dc2b_row4_col19, #T_0dc2b_row4_col21, #T_0dc2b_row4_col22, #T_0dc2b_row4_col23, #T_0dc2b_row5_col1, #T_0dc2b_row5_col2, #T_0dc2b_row5_col3, #T_0dc2b_row5_col4, #T_0dc2b_row5_col5, #T_0dc2b_row5_col6, #T_0dc2b_row5_col7, #T_0dc2b_row5_col8, #T_0dc2b_row5_col9, #T_0dc2b_row5_col11, #T_0dc2b_row5_col13, #T_0dc2b_row5_col14, #T_0dc2b_row5_col15, #T_0dc2b_row5_col16, #T_0dc2b_row5_col18, #T_0dc2b_row5_col19, #T_0dc2b_row5_col21, #T_0dc2b_row5_col22, #T_0dc2b_row5_col23, #T_0dc2b_row6_col1, #T_0dc2b_row6_col2, #T_0dc2b_row6_col3, #T_0dc2b_row6_col4, #T_0dc2b_row6_col7, #T_0dc2b_row6_col8, #T_0dc2b_row6_col9, #T_0dc2b_row6_col11, #T_0dc2b_row6_col18, #T_0dc2b_row6_col19, #T_0dc2b_row6_col21, #T_0dc2b_row6_col22, #T_0dc2b_row6_col23, #T_0dc2b_row7_col1, #T_0dc2b_row7_col2, #T_0dc2b_row7_col3, #T_0dc2b_row7_col4, #T_0dc2b_row7_col8, #T_0dc2b_row7_col9, #T_0dc2b_row7_col18, #T_0dc2b_row7_col19, #T_0dc2b_row7_col21 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_0dc2b_row1_col5, #T_0dc2b_row1_col17, #T_0dc2b_row2_col14, #T_0dc2b_row4_col20, #T_0dc2b_row5_col17, #T_0dc2b_row6_col10, #T_0dc2b_row7_col10 {
#   background-color: #02fdff;
#   color: #000000;
# }
# #T_0dc2b_row1_col6, #T_0dc2b_row5_col20 {
#   background-color: #06f9ff;
#   color: #000000;
# }
# #T_0dc2b_row1_col10, #T_0dc2b_row1_col14, #T_0dc2b_row4_col10, #T_0dc2b_row4_col17, #T_0dc2b_row5_col10, #T_0dc2b_row7_col7, #T_0dc2b_row7_col11, #T_0dc2b_row7_col22, #T_0dc2b_row7_col23 {
#   background-color: #01feff;
#   color: #000000;
# }
# #T_0dc2b_row1_col12, #T_0dc2b_row3_col12, #T_0dc2b_row4_col12, #T_0dc2b_row5_col12, #T_0dc2b_row6_col12 {
#   background-color: #1ce3ff;
#   color: #000000;
# }
# #T_0dc2b_row1_col13, #T_0dc2b_row2_col6, #T_0dc2b_row2_col15 {
#   background-color: #09f6ff;
#   color: #000000;
# }
# #T_0dc2b_row1_col15 {
#   background-color: #07f8ff;
#   color: #000000;
# }
# #T_0dc2b_row1_col16, #T_0dc2b_row1_col20 {
#   background-color: #05faff;
#   color: #000000;
# }
# #T_0dc2b_row2_col5, #T_0dc2b_row2_col20, #T_0dc2b_row6_col5, #T_0dc2b_row6_col14, #T_0dc2b_row6_col17 {
#   background-color: #03fcff;
#   color: #000000;
# }
# #T_0dc2b_row2_col13, #T_0dc2b_row6_col16, #T_0dc2b_row7_col20 {
#   background-color: #0af5ff;
#   color: #000000;
# }
# #T_0dc2b_row2_col16, #T_0dc2b_row6_col20 {
#   background-color: #08f7ff;
#   color: #000000;
# }
# #T_0dc2b_row6_col6, #T_0dc2b_row7_col14 {
#   background-color: #0cf3ff;
#   color: #000000;
# }
# #T_0dc2b_row6_col13 {
#   background-color: #14ebff;
#   color: #000000;
# }
# #T_0dc2b_row6_col15, #T_0dc2b_row7_col5 {
#   background-color: #0ef1ff;
#   color: #000000;
# }
# #T_0dc2b_row7_col6, #T_0dc2b_row7_col12, #T_0dc2b_row7_col13 {
#   background-color: #1de2ff;
#   color: #000000;
# }
# #T_0dc2b_row7_col15, #T_0dc2b_row7_col16 {
#   background-color: #1ee1ff;
#   color: #000000;
# }
# #T_0dc2b_row7_col17 {
#   background-color: #04fbff;
#   color: #000000;
# }
# </style>
# <table id="T_0dc2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0dc2b_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_0dc2b_level0_col1" class="col_heading level0 col1" >Month</th>
#       <th id="T_0dc2b_level0_col2" class="col_heading level0 col2" >Day</th>
#       <th id="T_0dc2b_level0_col3" class="col_heading level0 col3" >Hour</th>
#       <th id="T_0dc2b_level0_col4" class="col_heading level0 col4" >Minute</th>
#       <th id="T_0dc2b_level0_col5" class="col_heading level0 col5" >DHI</th>
#       <th id="T_0dc2b_level0_col6" class="col_heading level0 col6" >DNI</th>
#       <th id="T_0dc2b_level0_col7" class="col_heading level0 col7" >Dew Point</th>
#       <th id="T_0dc2b_level0_col8" class="col_heading level0 col8" >Surface Albedo</th>
#       <th id="T_0dc2b_level0_col9" class="col_heading level0 col9" >Wind Speed</th>
#       <th id="T_0dc2b_level0_col10" class="col_heading level0 col10" >Relative Humidity</th>
#       <th id="T_0dc2b_level0_col11" class="col_heading level0 col11" >Temperature</th>
#       <th id="T_0dc2b_level0_col12" class="col_heading level0 col12" >Pressure</th>
#       <th id="T_0dc2b_level0_col13" class="col_heading level0 col13" >Clearsky DNI</th>
#       <th id="T_0dc2b_level0_col14" class="col_heading level0 col14" >Clearsky DHI</th>
#       <th id="T_0dc2b_level0_col15" class="col_heading level0 col15" >Clearsky GHI</th>
#       <th id="T_0dc2b_level0_col16" class="col_heading level0 col16" >GHI</th>
#       <th id="T_0dc2b_level0_col17" class="col_heading level0 col17" >Solar Zenith Angle</th>
#       <th id="T_0dc2b_level0_col18" class="col_heading level0 col18" >Cloud Type</th>
#       <th id="T_0dc2b_level0_col19" class="col_heading level0 col19" >Fill Flag</th>
#       <th id="T_0dc2b_level0_col20" class="col_heading level0 col20" >Wind Direction</th>
#       <th id="T_0dc2b_level0_col21" class="col_heading level0 col21" >Precipitable Water</th>
#       <th id="T_0dc2b_level0_col22" class="col_heading level0 col22" >Global Horizontal UV Irradiance (280-400nm)</th>
#       <th id="T_0dc2b_level0_col23" class="col_heading level0 col23" >Global Horizontal UV Irradiance (295-385nm)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0dc2b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_0dc2b_row0_col0" class="data row0 col0" >8760.000000</td>
#       <td id="T_0dc2b_row0_col1" class="data row0 col1" >8760.000000</td>
#       <td id="T_0dc2b_row0_col2" class="data row0 col2" >8760.000000</td>
#       <td id="T_0dc2b_row0_col3" class="data row0 col3" >8760.000000</td>
#       <td id="T_0dc2b_row0_col4" class="data row0 col4" >8760.000000</td>
#       <td id="T_0dc2b_row0_col5" class="data row0 col5" >8760.000000</td>
#       <td id="T_0dc2b_row0_col6" class="data row0 col6" >8760.000000</td>
#       <td id="T_0dc2b_row0_col7" class="data row0 col7" >8760.000000</td>
#       <td id="T_0dc2b_row0_col8" class="data row0 col8" >8760.000000</td>
#       <td id="T_0dc2b_row0_col9" class="data row0 col9" >8760.000000</td>
#       <td id="T_0dc2b_row0_

# %%
actual_solar = pd.read_csv('Charlotte/653351892e546d5d55892a5e2a054320/Actual_35.25_-80.85_2006_DPV_37MW_5_Min.csv')
da_solar = pd.read_csv('Charlotte/653351892e546d5d55892a5e2a054320/DA_35.25_-80.85_2006_DPV_37MW_60_Min.csv')
ha4_solar = pd.read_csv('Charlotte/653351892e546d5d55892a5e2a054320/HA4_35.25_-80.85_2006_DPV_37MW_60_Min.csv')

# %%
# actual
actual_solar['LocalTime'] = pd.to_datetime(actual_solar['LocalTime'])
# adding separate time and date columns
actual_solar["Year"] = pd.to_datetime(actual_solar["LocalTime"]).dt.year
actual_solar['Day'] = pd.to_datetime(actual_solar['LocalTime']).dt.day
actual_solar['Month'] = pd.to_datetime(actual_solar['LocalTime']).dt.month
actual_solar["TIME"] = pd.to_datetime(actual_solar["LocalTime"]).dt.time
actual_solar["DATE"] = pd.to_datetime(actual_solar["LocalTime"]).dt.date
# add hours and minutes for ml models
actual_solar['Hour'] = pd.to_datetime(actual_solar['TIME'],format='%H:%M:%S').dt.hour
actual_solar['Minute'] = pd.to_datetime(actual_solar['TIME'],format='%H:%M:%S').dt.minute
actual_solar['TOTAL MINUTES PASS'] = actual_solar['Minute'] + actual_solar['Hour']*60
# remove other times, keep only 00 minutes
actual_solar = actual_solar[actual_solar['Minute'] == 0]

# day ahead
da_solar['LocalTime'] = pd.to_datetime(da_solar['LocalTime'])
# adding separate time and date columns
da_solar["Year"] = pd.to_datetime(da_solar["LocalTime"]).dt.year
da_solar['Day'] = pd.to_datetime(da_solar['LocalTime']).dt.day
da_solar['Month'] = pd.to_datetime(da_solar['LocalTime']).dt.month
da_solar["TIME"] = pd.to_datetime(da_solar["LocalTime"]).dt.time
da_solar["DATE"] = pd.to_datetime(da_solar["LocalTime"]).dt.date
# add hours and minutes for ml models
da_solar['Hour'] = pd.to_datetime(da_solar['TIME'],format='%H:%M:%S').dt.hour
da_solar['Minute'] = pd.to_datetime(da_solar['TIME'],format='%H:%M:%S').dt.minute
da_solar['TOTAL MINUTES PASS'] = da_solar['Minute'] + da_solar['Hour']*60

# 4 hour ahead
ha4_solar['LocalTime'] = pd.to_datetime(ha4_solar['LocalTime'])
# adding separate time and date columns
ha4_solar["Year"] = pd.to_datetime(ha4_solar["LocalTime"]).dt.year
ha4_solar['Day'] = pd.to_datetime(ha4_solar['LocalTime']).dt.day
ha4_solar['Month'] = pd.to_datetime(ha4_solar['LocalTime']).dt.month
ha4_solar["TIME"] = pd.to_datetime(ha4_solar["LocalTime"]).dt.time
ha4_solar["DATE"] = pd.to_datetime(ha4_solar["LocalTime"]).dt.date
# add hours and minutes for ml models
ha4_solar['Hour'] = pd.to_datetime(ha4_solar['TIME'],format='%H:%M:%S').dt.hour
ha4_solar['Minute'] = pd.to_datetime(ha4_solar['TIME'],format='%H:%M:%S').dt.minute
ha4_solar['TOTAL MINUTES PASS'] = ha4_solar['Minute'] + ha4_solar['Hour']*60
actual_solar
# Out:
#                  LocalTime  Power(MW)  Year  Day  Month      TIME        DATE  \
# 0      2006-01-01 00:00:00        0.0  2006    1      1  00:00:00  2006-01-01
# 12     2006-01-01 01:00:00        0.0  2006    1      1  01:00:00  2006-01-01
# 24     2006-01-01 02:00:00        0.0  2006    1      1  02:00:00  2006-01-01
# 36     2006-01-01 03:00:00        0.0  2006    1      1  03:00:00  2006-01-01
# 48     2006-01-01 04:00:00        0.0  2006    1      1  04:00:00  2006-01-01
# ...                    ...        ...   ...  ...    ...       ...         ...
# 105060 2006-12-31 19:00:00        0.0  2006   31     12  19:00:00  2006-12-31
# 105072 2006-12-31 20:00:00        0.0  2006   31     12  20:00:00  2006-12-31
# 105084 2006-12-31 21:00:00        0.0  2006   31     12  21:00:00  2006-12-31
# 105096 2006-12-31 22:00:00        0.0  2006   31     12  22:00:00  2006-12-31
# 105108 2006-12-31 23:00:00        0.0  2006   31     12  23:00:00  2006-12-31
#
#         Hour  Minute  TOTAL MINUTES PASS
# 0          0       0                   0
# 12         1       0                  60
# 24         2       0                 120
# 36         3       0                 180
# 48         4       0                 240
# ...      ...     ...                 ...
# 105060    19       0                1140
# 105072    20       0                1200
# 105084    21       0                1260
# 105096    22       0                1320
# 105108    23       0                1380
#
# [8760 rows x 10 columns]

# %%
print(actual_solar.info())
print(actual_solar.isnull().sum())
actual_solar.describe().style.background_gradient(cmap='cool')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8760 entries, 0 to 105108
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   LocalTime           8760 non-null   datetime64[ns]
#  1   Power(MW)           8760 non-null   float64
#  2   Year                8760 non-null   int64
#  3   Day                 8760 non-null   int64
#  4   Month               8760 non-null   int64
#  5   TIME                8760 non-null   object
#  6   DATE                8760 non-null   object
#  7   Hour                8760 non-null   int64
#  8   Minute              8760 non-null   int64
#  9   TOTAL MINUTES PASS  8760 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(2)
# memory usage: 752.8+ KB
# None
# LocalTime             0
# Power(MW)             0
# Year                  0
# Day                   0
# Month                 0
# TIME                  0
# DATE                  0
# Hour                  0
# Minute                0
# TOTAL MINUTES PASS    0
# dtype: int64
# <style type="text/css">
# #T_60425_row0_col0, #T_60425_row0_col1, #T_60425_row0_col2, #T_60425_row0_col3, #T_60425_row0_col4, #T_60425_row0_col5, #T_60425_row0_col6 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_60425_row1_col0, #T_60425_row1_col2, #T_60425_row1_col3, #T_60425_row1_col4, #T_60425_row1_col5, #T_60425_row2_col0, #T_60425_row2_col1, #T_60425_row2_col2, #T_60425_row2_col3, #T_60425_row2_col4, #T_60425_row2_col5, #T_60425_row3_col0, #T_60425_row3_col2, #T_60425_row3_col3, #T_60425_row3_col4, #T_60425_row3_col5, #T_60425_row3_col6, #T_60425_row4_col0, #T_60425_row4_col2, #T_60425_row4_col3, #T_60425_row4_col4, #T_60425_row4_col5, #T_60425_row5_col0, #T_60425_row5_col2, #T_60425_row5_col3, #T_60425_row5_col4, #T_60425_row5_col5, #T_60425_row6_col0, #T_60425_row6_col2, #T_60425_row6_col3, #T_60425_row6_col4, #T_60425_row6_col5, #T_60425_row7_col0, #T_60425_row7_col2, #T_60425_row7_col3, #T_60425_row7_col4, #T_60425_row7_col5 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_60425_row1_col1, #T_60425_row3_col1, #T_60425_row4_col1, #T_60425_row5_col1, #T_60425_row6_col1, #T_60425_row7_col1 {
#   background-color: #3ac5ff;
#   color: #000000;
# }
# #T_60425_row1_col6, #T_60425_row5_col6 {
#   background-color: #14ebff;
#   color: #000000;
# }
# #T_60425_row2_col6 {
#   background-color: #0cf3ff;
#   color: #000000;
# }
# #T_60425_row4_col6 {
#   background-color: #0af5ff;
#   color: #000000;
# }
# #T_60425_row6_col6 {
#   background-color: #1ee1ff;
#   color: #000000;
# }
# #T_60425_row7_col6 {
#   background-color: #28d7ff;
#   color: #000000;
# }
# </style>
# <table id="T_60425">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60425_level0_col0" class="col_heading level0 col0" >Power(MW)</th>
#       <th id="T_60425_level0_col1" class="col_heading level0 col1" >Year</th>
#       <th id="T_60425_level0_col2" class="col_heading level0 col2" >Day</th>
#       <th id="T_60425_level0_col3" class="col_heading level0 col3" >Month</th>
#       <th id="T_60425_level0_col4" class="col_heading level0 col4" >Hour</th>
#       <th id="T_60425_level0_col5" class="col_heading level0 col5" >Minute</th>
#       <th id="T_60425_level0_col6" class="col_heading level0 col6" >TOTAL MINUTES PASS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60425_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_60425_row0_col0" class="data row0 col0" >8760.000000</td>
#       <td id="T_60425_row0_col1" class="data row0 col1" >8760.000000</td>
#       <td id="T_60425_row0_col2" class="data row0 col2" >8760.000000</td>
#       <td id="T_60425_row0_col3" class="data row0 col3" >8760.000000</td>
#       <td id="T_60425_row0_col4" class="data row0 col4" >8760.000000</td>
#       <td id="T_60425_row0_col5" class="data row0 col5" >8760.000000</td>
#       <td id="T_60425_row0_col6" class="data row0 col6" >8760.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60425_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_60425_row1_col0" class="data row1 col0" >5.707991</td>
#       <td id="T_60425_row1_col1" class="data row1 col1" >2006.000000</td>
#       <td id="T_60425_row1_col2" class="data row1 col2" >15.720548</td>
#       <td id="T_60425_row1_col3" class="data row1 col3" >6.526027</td>
#       <td id="T_60425_row1_col4" class="data row1 col4" >11.500000</td>
#       <td id="T_60425_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_60425_row1_col6" class="data row1 col6" >690.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60425_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_60425_row2_col0" class="data row2 col0" >8.421007</td>
#       <td id="T_60425_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_60425_row2_col2" class="data row2 col2" >8.796749</td>
#       <td id="T_60425_row2_col3" class="data row2 col3" >3.448048</td>
#       <td id="T_60425_row2_col4" class="data row2 col4" >6.922582</td>
#       <td id="T_60425_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_60425_row2_col6" class="data row2 col6" >415.354901</td>
#     </tr>
#     <tr>
#       <th id="T_60425_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_60425_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_60425_row3_col1" class="data row3 col1" >2006.000000</td>
#       <td id="T_60425_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_60425_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_60425_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_60425_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_60425_row3_col6" class="data row3 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60425_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_60425_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_60425_row4_col1" class="data row4 col1" >2006.000000</td>
#       <td id="T_60425_row4_col2" class="data row4 col2" >8.000000</td>
#       <td id="T_60425_row4_col3" class="data row4 col3" >4.000000</td>
#       <td id="T_60425_row4_col4" class="data row4 col4" >5.750000</td>
#       <td id="T_60425_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_60425_row4_col6" class="data row4 col6" >345.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60425_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_60425_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_60425_row5_col1" class="data row5 col1" >2006.000000</td>
#       <td id="T_60425_row5_col2" class="data row5 col2" >16.000000</td>
#       <td id="T_60425_row5_col3" class="data row5 col3" >7.000000</td>
#       <td id="T_60425_row5_col4" class="data row5 col4" >11.500000</td>
#       <td id="T_60425_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_60425_row5_col6" class="data row5 col6" >690.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60425_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_60425_row6_col0" class="data row6 col0" >10.300000</td>
#       <td id="T_60425_row6_col1" class="data row6 col1" >2006.000000</td>
#       <td id="T_60425_row6_col2" class="data row6 col2" >23.000000</td>
#       <td id="T_60425_row6_col3" class="data row6 col3" >10.000000</td>
#       <td id="T_60425_row6_col4" class="data row6 col4" >17.250000</td>
#       <td id="T_60425_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_60425_row6_col6" class="data row6 col6" >1035.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60425_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_60425_row7_col0" class="data row7 col0" >31.400000</td>
#       <td id="T_60425_row7_col1" class="data row7 col1" >2006.000000</td>
#       <td id="T_60425_row7_col2" class="data row7 col2" >31.000000</td>
#       <td id="T_60425_row7_col3" class="data row7 col3" >12.000000</td>
#       <td id="T_60425_row7_col4" class="data row7 col4" >23.000000</td>
#       <td id="T_60425_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_60425_row7_col6" class="data row7 col6" >1380.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ignoring times with 0 power generation
sns.displot(data=actual_solar[actual_solar['Power(MW)'] > 0], x="Power(MW)", kde=True, bins = 330,color = "red", facecolor = "green",height = 7, aspect = 4);

# %%
temp = actual_solar[actual_solar['Month'] < 3]
solar_dc = temp.pivot_table(values='Power(MW)', index='TIME', columns='DATE')

def Daywise_plot(data= None, row = None, col = None, title='Power(MW)'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='red')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='blue')
        
# look at the first 2 months
Daywise_plot(data=solar_dc, row=30, col=2)

# %%
daily_dc = temp.groupby('DATE')['Power(MW)'].agg('sum')

ax = daily_dc.sort_values(ascending=False).plot.bar(figsize=(17,5), legend=True,color='red')
plt.title('Daily Power(MW)')
plt.show()

# %%
temp = irradiance_data[irradiance_data['Month'] < 3]
solar_dc = temp.pivot_table(values='DNI', index='TIME', columns='DATE')

def Daywise_plot(data= None, row = None, col = None, title='DHI'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='darkgreen')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='blue')
        
Daywise_plot(data=solar_dc, row=30, col=2)

# %%
daily_ambient_temp = temp.groupby('DATE')['DHI'].agg('sum')

daily_ambient_temp.sort_values(ascending=False).plot.bar(figsize=(17,5), legend=True,color='darkgreen')
plt.title('AMBIENT_TEMPERATURE')
plt.show()

# %%
df2 = pd.merge(irradiance_data, actual_solar, how='inner', on='LocalTime')
df2 = df2[(df2['Power(MW)'] > 0) |  (df2['DHI'] > 0)|  (df2['DNI'] > 0)]

X = df2[['DHI', 'DNI', 'Dew Point',
       'Surface Albedo', 'Wind Speed', 'Relative Humidity', 'Temperature',
       'Pressure', 'Clearsky DHI', 'Clearsky DNI', 'Clearsky GHI', 'GHI',
       'Solar Zenith Angle', 'Cloud Type', 'Fill Flag', 'Wind Direction',
       'Precipitable Water', 'Global Horizontal UV Irradiance (280-400nm)',
       'Global Horizontal UV Irradiance (295-385nm)']]
y = df2['Power(MW)']
df2
# Out:
#       Year_x  Month_x  Day_x  Hour_x  Minute_x  DHI  DNI  Dew Point  \
# 8       2006        1      1       8         0   23  391          1
# 9       2006        1      1       9         0   62  521          1
# 10      2006        1      1      10         0   60  837          2
# 11      2006        1      1      11         0   67  902          1
# 12      2006        1      1      12         0   69  936          0
# ...      ...      ...    ...     ...       ...  ...  ...        ...
# 8749    2006       12     31      13         0  114    0         13
# 8750    2006       12     31      14         0   90    0         13
# 8751    2006       12     31      15         0   48    0         13
# 8752    2006       12     31      16         0   25    0         14
# 8753    2006       12     31      17         0    4    0         14
#
#       Surface Albedo  Wind Speed  ...      DATE_x  Power(MW)  Year_y  Day_y  \
# 8              0.116         0.3  ...  2006-01-01        0.0    2006      1
# 9              0.116         0.3  ...  2006-01-01        8.6    2006      1
# 10             0.116         0.1  ...  2006-01-01       10.0    2006      1
# 11             0.116         0.1  ...  2006-01-01       15.9    2006      1
# 12             0.116         0.1  ...  2006-01-01       18.3    2006      1
# ...              ...         ...  ...         ...        ...     ...    ...
# 8749           0.113         0.9  ...  2006-12-31        1.7    2006     31
# 8750           0.113         0.9  ...  2006-12-31        0.3    2006     31
# 8751           0.113         0.9  ...  2006-12-31        0.2    2006     31
# 8752           0.113         0.8  ...  2006-12-31        0.0    2006     31
# 8753           0.113         0.9  ...  2006-12-31        0.0    2006     31
#
#       Month_y    TIME_y      DATE_y  Hour_y  Minute_y  TOTAL MINUTES PASS
# 8           1  08:00:00  2006-01-01       8         0                 480
# 9           1  09:00:00  2006-01-01       9         0                 540
# 10          1  10:00:00  2006-01-01      10         0                 600
# 11          1  11:00:00  2006-01-01      11         0                 660
# 12          1  12:00:00  2006-01-01      12         0                 720
# ...       ...       ...         ...     ...       ...                 ...
# 8749       12  13:00:00  2006-12-31      13         0                 780
# 8750       12  14:00:00  2006-12-31      14         0                 840
# 8751       12  15:00:00  2006-12-31      15         0                 900
# 8752       12  16:00:00  2006-12-31      16         0                 960
# 8753       12  17:00:00  2006-12-31      17         0                1020
#
# [4356 rows x 36 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=69)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
score_lr = 100*lr_clf.score(X_test,y_test)
print(f'LR Model score = {score_lr:4.4f}%')
# Out:
# LR Model score = 83.6763%

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred_lr = lr.predict(X_test)
R2_Score_lr = round(r2_score(y_pred_lr,y_test) * 100, 2)

print("R2 Score : ",R2_Score_lr,"%")
# Out:
# R2 Score :  81.29 %

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)
y_pred_rfr = lr.predict(X_test)
R2_Score_rfr = round(r2_score(y_pred_rfr,y_test) * 100, 2)

print("R2 Score : ",R2_Score_rfr,"%")
# Out:
# R2 Score :  81.29 %

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train,y_train)

y_pred_dtr = lr.predict(X_test)
R2_Score_dtr = round(r2_score(y_pred_dtr,y_test) * 100, 2)

print("R2 Score : ",R2_Score_dtr,"%")
# Out:
# R2 Score :  81.29 %

# %%
prediction = rfr.predict(X_test)
print(prediction)
# Out:
# [2.1631e+01 2.1204e+01 4.8400e+00 1.2240e+00 6.4700e-01 1.1407e+01
#  9.1900e+00 6.1220e+00 3.1240e+00 3.8490e+00 5.3000e-02 2.2756e+01
#  9.4400e-01 3.5540e+00 0.0000e+00 2.3815e+01 6.3780e+00 2.3925e+01
#  5.9000e-02 2.4741e+01 4.5070e+00 2.5048e+01 1.7053e+01 4.6220e+00
#  1.0355e+01 2.8560e+00 9.9510e+00 1.9000e-02 8.0800e-01 1.2800e+00
#  2.0590e+01 9.5340e+00 0.0000e+00 1.0191e+01 9.9960e+00 1.0560e+00
#  2.5154e+01 1.8547e+01 2.2520e+00 2.2664e+01 6.1000e-02 2.3056e+01
#  6.0340e+00 1.8822e+01 2.5823e+01 7.0000e-03 1.9284e+01 1.9581e+01
#  1.9316e+01 9.6480e+00 2.8011e+01 7.0000e-03 1.1176e+01 1.3913e+01
#  9.0830e+00 2.4445e+01 2.2908e+01 2.1521e+01 1.4365e+01 0.0000e+00
#  6.5000e-02 1.1084e+01 2.6000e-02 8.9420e+00 1.5705e+01 1.4966e+01
#  1.8809e+01 2.4648e+01 1.1362e+01 6.2450e+00 1.1380e+00 1.1157e+01
#  1.3877e+01 1.4019e+01 9.9560e+00 3.6610e+00 1.9779e+01 1.8999e+01
#  1.0080e+01 3.3210e+00 0.0000e+00 3.6770e+00 1.6656e+01 0.0000e+00
#  5.3850e+00 2.1126e+01 6.1070e+00 2.0000e-03 1.0612e+01 2.1676e+01
#  0.0000e+00 2.5627e+01 1.9420e+00 1.4365e+01 2.4882e+01 1.9036e+01
#  6.0450e+00 1.9642e+01 1.9798e+01 4.9900e-01 1.7965e+01 7.2340e+00
#  4.2650e+00 2.0645e+01 1.8411e+01 2.3220e+00 0.0000e+00 2.5870e+00
#  8.4250e+00 6.6980e+00 5.1010e+00 6.2070e+00 8.0050e+00 1.1620e+01
#  0.0000e+00 8.9280e+00]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction})
cross_checking.head()
# Out:
#       Actual  Predicted
# 662     22.0     21.631
# 6060    24.3     21.204
# 6416     0.2      4.840
# 4231     1.5      1.224
# 2394     0.8      0.647

# %%
cross_checking['Error'] = cross_checking['Actual'] - cross_checking['Predicted']
cross_checking.head()
# Out:
#       Actual  Predicted  Error
# 662     22.0     21.631  0.369
# 6060    24.3     21.204  3.096
# 6416     0.2      4.840 -4.640
# 4231     1.5      1.224  0.276
# 2394     0.8      0.647  0.153

# %%
cross_checking_final  = cross_checking[cross_checking['Error'] <= 20]
cross_checking_final.sample(25).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'font-family': 'Lucida Calligraphy',
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_6655b_row0_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row0_col1, #T_6655b_row0_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row1_col0 {
#   background-color: #e16751;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row1_col1 {
#   background-color: #e9785d;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row1_col2, #T_6655b_row13_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row2_col0 {
#   background-color: #d65244;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row2_col1 {
#   background-color: #edd1c2;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row2_col2, #T_6655b_row9_col0, #T_6655b_row9_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row3_col0, #T_6655b_row3_col1, #T_6655b_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row3_col2 {
#   background-color: #aec9fc;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row4_col0 {
#   background-color: #f7b99e;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row4_col1 {
#   background-color: #ee8669;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row5_col0, #T_6655b_row5_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row5_col2 {
#   background-color: #aac7fd;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row6_col1 {
#   background-color: #df634e;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row6_col2 {
#   background-color: #9ebeff;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row7_col0 {
#   background-color: #f6bfa6;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row7_col1 {
#   background-color: #efcfbf;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row7_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row8_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row8_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row8_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row9_col2 {
#   background-color: #96b7ff;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row10_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row10_col1 {
#   background-color: #f5a081;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row10_col2 {
#   background-color: #f5c4ac;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row11_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row11_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row11_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row12_col0, #T_6655b_row14_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row12_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row12_col2 {
#   background-color: #90b2fe;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row13_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row13_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row14_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row14_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row15_col0 {
#   background-color: #d9dce1;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row15_col1 {
#   background-color: #cfdaea;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row15_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row16_col0 {
#   background-color: #f7b89c;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row16_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row16_col2 {
#   background-color: #c7d7f0;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row17_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row17_col1 {
#   background-color: #b7cff9;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row17_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row18_col0 {
#   background-color: #f59f80;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row18_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row18_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row19_col0 {
#   background-color: #8db0fe;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row19_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row19_col2 {
#   background-color: #d1dae9;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row20_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6655b_row20_col1 {
#   background-color: #bed2f6;
#   color: #000000;
#   font-family: Lucida Calligrap

# %%
# evaluate an xgboost regression model on the housing dataset
from numpy import absolute
from pandas import read_csv
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from xgboost import XGBRegressor

model = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
scores = absolute(scores)
print('Mean MAE: %.3f (%.3f)' % (scores.mean(), scores.std()) )
# Out:
# Mean MAE: 2.027 (0.092)

# %%
model.fit(X_train,y_train)
y_pred_lr = model.predict(X_test)
R2_Score_lr = round(r2_score(y_pred_lr,y_test) * 100, 2)

print("R2 Score : ",R2_Score_lr,"%")
# Out:
# R2 Score :  84.88 %
